# %% [markdown]
# # Data Wrangling with Python
#
# ### This workshop provides an introduction to the data analysis suite used for data science projects in Python.
#
# We will cover the following commonly used libraries (click on links for respective user guide/documentation):
# - [Pandas](https://pandas.pydata.org/docs/user_guide/index.html): Manipulating and analyzing tabular data
# - [NumPy](https://numpy.org/doc/stable/user/quickstart.html): Linear algebra operations
# - [SciPy](https://docs.scipy.org/doc/scipy/getting_started.html): Extension over NumPy for scientific computation
# - [Seaborn](https://seaborn.pydata.org/tutorial.html): A high-level library for data visualization

# %% [markdown]
# ## Pandas

# %%
import pandas as pd

# %%
df = pd.read_csv('titanic.csv')

# %%
df.shape
# Out:
# (1309, 14)

# %%
df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %% [markdown]
# ## Data Dictionary
#
# - survival - Survival (0 = No; 1 = Yes)
# - class - Passenger Class (1 = 1st; 2 = 2nd; 3 = 3rd)
# - name - Name
# - sex - Sex
# - age - Age
# - sibsp - Number of Siblings/Spouses Aboard
# - parch - Number of Parents/Children Aboard
# - ticket - Ticket Number
# - fare - Passenger Fare
# - cabin - Cabin
# - embarked - Port of Embarkation (C = Cherbourg; Q = Queenstown; S = Southampton)
# - boat - Lifeboat (if survived)
# - body - Body number (if did not survive and body was recovered)

# %%
df.head(2).T
# Out:
#                                        0                                1
# pclass                                 1                                1
# survived                               1                                1
# name       Allen, Miss. Elisabeth Walton   Allison, Master. Hudson Trevor
# sex                               female                             male
# age                                 29.0                           0.9167
# sibsp                                  0                                1
# parch                                  0                                2
# ticket                             24160                           113781
# fare                            211.3375                           151.55
# cabin                                 B5                          C22 C26
# embarked                               S                                S
# boat                                   2                               11
# body                                 NaN                              NaN
# home.dest                   St Louis, MO  Montreal, PQ / Chesterville, ON

# %%
df.dtypes
# Out:
# pclass         int64
# survived       int64
# name          object
# sex           object
# age          float64
# sibsp          int64
# parch          int64
# ticket        object
# fare         float64
# cabin         object
# embarked      object
# boat          object
# body         float64
# home.dest     object
# dtype: object

# %%
df['survived'].value_counts(normalize = True)
# Out:
# 0    0.618029
# 1    0.381971
# Name: survived, dtype: float64

# %%
df.isnull().sum(axis = 0)
# Out:
# pclass          0
# survived        0
# name            0
# sex             0
# age           264
# sibsp           0
# parch           0
# ticket          0
# fare            1
# cabin        1014
# embarked        2
# boat          823
# body         1188
# home.dest     564
# dtype: int64

# %%
# df [ filter_logic ]
df[df['age'].isnull()]
# Out:
#       pclass  survived                                           name     sex  \
# 9          1         0                        Artagaveytia, Mr. Ramon    male
# 15         1         0                            Baumann, Mr. John D    male
# 37         1         1  Bradley, Mr. George ("George Arthur Brayton")    male
# 40         1         0                      Brewe, Dr. Arthur Jackson    male
# 46         1         0                          Cairns, Mr. Alexander    male
# ...      ...       ...                                            ...     ...
# 1293       3         0              Williams, Mr. Howard Hugh "Harry"    male
# 1297       3         0                         Wiseman, Mr. Phillippe    male
# 1302       3         0                              Yousif, Mr. Wazli    male
# 1303       3         0                          Yousseff, Mr. Gerious    male
# 1305       3         0                          Zabour, Miss. Thamine  female
#
#       age  sibsp  parch      ticket     fare cabin embarked boat  body  \
# 9     NaN      0      0    PC 17609  49.5042   NaN        C  NaN  22.0
# 15    NaN      0      0    PC 17318  25.9250   NaN        S  NaN   NaN
# 37    NaN      0      0      111427  26.5500   NaN        S    9   NaN
# 40    NaN      0      0      112379  39.6000   NaN        C  NaN   NaN
# 46    NaN      0      0      113798  31.0000   NaN        S  NaN   NaN
# ...   ...    ...    ...         ...      ...   ...      ...  ...   ...
# 1293  NaN      0      0    A/5 2466   8.0500   NaN        S  NaN   NaN
# 1297  NaN      0      0  A/4. 34244   7.2500   NaN        S  NaN   NaN
# 1302  NaN      0      0        2647   7.2250   NaN        C  NaN   NaN
# 1303  NaN      0      0        2627  14.4583   NaN        C  NaN   NaN
# 1305  NaN      1      0        2665  14.4542   NaN        C  NaN   NaN
#
#                 home.dest
# 9     Montevideo, Uruguay
# 15           New York, NY
# 37        Los Angeles, CA
# 40       Philadelphia, PA
# 46                    NaN
# ...                   ...
# 1293                  NaN
# 1297                  NaN
# 1302                  NaN
# 1303                  NaN
# 1305                  NaN
#
# [264 rows x 14 columns]

# %%
df[df['age'].isnull()]['age']
# Out:
# 9      NaN
# 15     NaN
# 37     NaN
# 40     NaN
# 46     NaN
#         ..
# 1293   NaN
# 1297   NaN
# 1302   NaN
# 1303   NaN
# 1305   NaN
# Name: age, Length: 264, dtype: float64

# %%
df['age'].mean()
# Out:
# 29.841786315789474

# %%
import numpy as np

df['age'] = np.where(df['age'].isnull(), df['age'].mean(), df['age'])

# %%
df.groupby('survived')['age'].agg(['mean', 'count'])
# Out:
#                mean  count
# survived
# 0         30.329252    809
# 1         29.053068    500

# %%
df.groupby('embarked')['age'].mean()
# Out:
# embarked
# C    31.644748
# Q    29.349190
# S    29.331363
# Name: age, dtype: float64

# %%
df.groupby(['survived', 'embarked'])['age'].agg(['count', 'mean'])
# Out:
#                    count       mean
# survived embarked
# 0        C           120  32.583444
#          Q            79  30.010823
#          S           610  29.927043
# 1        C           150  30.893792
#          Q            44  28.161259
#          S           304  28.136084

# %%
survived = df[['survived', 'embarked', 'age']].replace({0: 'Did Not Survive', 1: 'Survived'})

survived = df[['survived', 'embarked', 'age']].replace({'survived': 
                                                        {0: 'Did Not Survive', 
                                                         1: 'Survived'}
                                                       })
survived.groupby(['survived', 'embarked'])['age'].agg(['count', 'mean'])
# Out:
#                           count       mean
# survived        embarked
# Did Not Survive C           120  32.583444
#                 Q            79  30.010823
#                 S           610  29.927043
# Survived        C           150  30.893792
#                 Q            44  28.161259
#                 S           304  28.136084

# %%
survived.groupby(['survived', 'embarked'])['age'].agg(['count', 'mean']).style.background_gradient(cmap='viridis')
# Out:
# <style type="text/css">
# #T_d6f0e_row0_col0 {
#   background-color: #472f7d;
#   color: #f1f1f1;
# }
# #T_d6f0e_row0_col1, #T_d6f0e_row2_col0 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_d6f0e_row1_col0 {
#   background-color: #481769;
#   color: #f1f1f1;
# }
# #T_d6f0e_row1_col1 {
#   background-color: #287d8e;
#   color: #f1f1f1;
# }
# #T_d6f0e_row2_col1 {
#   background-color: #29798e;
#   color: #f1f1f1;
# }
# #T_d6f0e_row3_col0 {
#   background-color: #423f85;
#   color: #f1f1f1;
# }
# #T_d6f0e_row3_col1 {
#   background-color: #26ad81;
#   color: #f1f1f1;
# }
# #T_d6f0e_row4_col0, #T_d6f0e_row5_col1 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_d6f0e_row4_col1 {
#   background-color: #440256;
#   color: #f1f1f1;
# }
# #T_d6f0e_row5_col0 {
#   background-color: #24868e;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_d6f0e">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d6f0e_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_d6f0e_level0_col1" class="col_heading level0 col1" >mean</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >survived</th>
#       <th class="index_name level1" >embarked</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d6f0e_level0_row0" class="row_heading level0 row0" rowspan="3">Did Not Survive</th>
#       <th id="T_d6f0e_level1_row0" class="row_heading level1 row0" >C</th>
#       <td id="T_d6f0e_row0_col0" class="data row0 col0" >120</td>
#       <td id="T_d6f0e_row0_col1" class="data row0 col1" >32.583444</td>
#     </tr>
#     <tr>
#       <th id="T_d6f0e_level1_row1" class="row_heading level1 row1" >Q</th>
#       <td id="T_d6f0e_row1_col0" class="data row1 col0" >79</td>
#       <td id="T_d6f0e_row1_col1" class="data row1 col1" >30.010823</td>
#     </tr>
#     <tr>
#       <th id="T_d6f0e_level1_row2" class="row_heading level1 row2" >S</th>
#       <td id="T_d6f0e_row2_col0" class="data row2 col0" >610</td>
#       <td id="T_d6f0e_row2_col1" class="data row2 col1" >29.927043</td>
#     </tr>
#     <tr>
#       <th id="T_d6f0e_level0_row3" class="row_heading level0 row3" rowspan="3">Survived</th>
#       <th id="T_d6f0e_level1_row3" class="row_heading level1 row3" >C</th>
#       <td id="T_d6f0e_row3_col0" class="data row3 col0" >150</td>
#       <td id="T_d6f0e_row3_col1" class="data row3 col1" >30.893792</td>
#     </tr>
#     <tr>
#       <th id="T_d6f0e_level1_row4" class="row_heading level1 row4" >Q</th>
#       <td id="T_d6f0e_row4_col0" class="data row4 col0" >44</td>
#       <td id="T_d6f0e_row4_col1" class="data row4 col1" >28.161259</td>
#     </tr>
#     <tr>
#       <th id="T_d6f0e_level1_row5" class="row_heading level1 row5" >S</th>
#       <td id="T_d6f0e_row5_col0" class="data row5 col0" >304</td>
#       <td id="T_d6f0e_row5_col1" class="data row5 col1" >28.136084</td>
#     </tr>
#   </tbody>
# </table>

# %%
df['fare'].mean()
# Out:
# 33.29547928134572

# %%
df['fare'].median()
# Out:
# 14.4542

# %%
df['age_bracket'] = pd.cut(df['age'], bins = 3, labels = ['Low', 'Medium', 'High'])
df['age_bracket'].value_counts()
# Out:
# Medium    759
# Low       474
# High       76
# Name: age_bracket, dtype: int64

# %%
df.pivot_table(index = ['embarked'], columns = ['sex'], values = ['survived'], aggfunc='mean')
# Out:
#           survived
# sex         female      male
# embarked
# C         0.902655  0.305732
# Q         0.616667  0.111111
# S         0.680412  0.170144

# %%
df.pivot_table(index = ['embarked'], columns = ['sex'], values = ['survived'], aggfunc='mean', margins = True)
# Out:
#           survived
# sex         female      male       All
# embarked
# C         0.902655  0.305732  0.555556
# Q         0.616667  0.111111  0.357724
# S         0.680412  0.170144  0.332604
# All       0.726293  0.190985  0.381025

# %%
df.pivot_table(index = ['embarked'], 
               columns = ['sex'], 
               values = ['survived'], 
               aggfunc='mean', 
               margins = True).style.background_gradient(cmap='YlOrRd_r').format(precision=2)
# Out:
# <style type="text/css">
# #T_b27a0_row0_col0, #T_b27a0_row0_col1, #T_b27a0_row0_col2 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_b27a0_row1_col0, #T_b27a0_row1_col1, #T_b27a0_row2_col2 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_b27a0_row1_col2 {
#   background-color: #b60026;
#   color: #f1f1f1;
# }
# #T_b27a0_row2_col0 {
#   background-color: #db141e;
#   color: #f1f1f1;
# }
# #T_b27a0_row2_col1 {
#   background-color: #ed3022;
#   color: #f1f1f1;
# }
# #T_b27a0_row3_col0 {
#   background-color: #fc532b;
#   color: #f1f1f1;
# }
# #T_b27a0_row3_col1 {
#   background-color: #fc612f;
#   color: #f1f1f1;
# }
# #T_b27a0_row3_col2 {
#   background-color: #d9131f;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b27a0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b27a0_level0_col0" class="col_heading level0 col0" colspan="3">survived</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >sex</th>
#       <th id="T_b27a0_level1_col0" class="col_heading level1 col0" >female</th>
#       <th id="T_b27a0_level1_col1" class="col_heading level1 col1" >male</th>
#       <th id="T_b27a0_level1_col2" class="col_heading level1 col2" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >embarked</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b27a0_level0_row0" class="row_heading level0 row0" >C</th>
#       <td id="T_b27a0_row0_col0" class="data row0 col0" >0.90</td>
#       <td id="T_b27a0_row0_col1" class="data row0 col1" >0.31</td>
#       <td id="T_b27a0_row0_col2" class="data row0 col2" >0.56</td>
#     </tr>
#     <tr>
#       <th id="T_b27a0_level0_row1" class="row_heading level0 row1" >Q</th>
#       <td id="T_b27a0_row1_col0" class="data row1 col0" >0.62</td>
#       <td id="T_b27a0_row1_col1" class="data row1 col1" >0.11</td>
#       <td id="T_b27a0_row1_col2" class="data row1 col2" >0.36</td>
#     </tr>
#     <tr>
#       <th id="T_b27a0_level0_row2" class="row_heading level0 row2" >S</th>
#       <td id="T_b27a0_row2_col0" class="data row2 col0" >0.68</td>
#       <td id="T_b27a0_row2_col1" class="data row2 col1" >0.17</td>
#       <td id="T_b27a0_row2_col2" class="data row2 col2" >0.33</td>
#     </tr>
#     <tr>
#       <th id="T_b27a0_level0_row3" class="row_heading level0 row3" >All</th>
#       <td id="T_b27a0_row3_col0" class="data row3 col0" >0.73</td>
#       <td id="T_b27a0_row3_col1" class="data row3 col1" >0.19</td>
#       <td id="T_b27a0_row3_col2" class="data row3 col2" >0.38</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.pivot_table(index = ['age_bracket'], 
               columns = ['sex'], 
               values = ['survived'], 
               aggfunc='mean',
               margins = True).style.bar().format(precision=2)
# Out:
# <style type="text/css">
# #T_a768c_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 80.4%, transparent 80.4%);
# }
# #T_a768c_row0_col1, #T_a768c_row0_col2, #T_a768c_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_a768c_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 81.8%, transparent 81.8%);
# }
# #T_a768c_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 77.3%, transparent 77.3%);
# }
# #T_a768c_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 85.7%, transparent 85.7%);
# }
# #T_a768c_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 43.5%, transparent 43.5%);
# }
# #T_a768c_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 87.8%, transparent 87.8%);
# }
# #T_a768c_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 82.2%, transparent 82.2%);
# }
# #T_a768c_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 83.0%, transparent 83.0%);
# }
# #T_a768c_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 91.0%, transparent 91.0%);
# }
# </style>
# <table id="T_a768c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a768c_level0_col0" class="col_heading level0 col0" colspan="3">survived</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >sex</th>
#       <th id="T_a768c_level1_col0" class="col_heading level1 col0" >female</th>
#       <th id="T_a768c_level1_col1" class="col_heading level1 col1" >male</th>
#       <th id="T_a768c_level1_col2" class="col_heading level1 col2" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >age_bracket</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a768c_level0_row0" class="row_heading level0 row0" >Low</th>
#       <td id="T_a768c_row0_col0" class="data row0 col0" >0.71</td>
#       <td id="T_a768c_row0_col1" class="data row0 col1" >0.23</td>
#       <td id="T_a768c_row0_col2" class="data row0 col2" >0.42</td>
#     </tr>
#     <tr>
#       <th id="T_a768c_level0_row1" class="row_heading level0 row1" >Medium</th>
#       <td id="T_a768c_row1_col0" class="data row1 col0" >0.72</td>
#       <td id="T_a768c_row1_col1" class="data row1 col1" >0.18</td>
#       <td id="T_a768c_row1_col2" class="data row1 col2" >0.36</td>
#     </tr>
#     <tr>
#       <th id="T_a768c_level0_row2" class="row_heading level0 row2" >High</th>
#       <td id="T_a768c_row2_col0" class="data row2 col0" >0.88</td>
#       <td id="T_a768c_row2_col1" class="data row2 col1" >0.10</td>
#       <td id="T_a768c_row2_col2" class="data row2 col2" >0.37</td>
#     </tr>
#     <tr>
#       <th id="T_a768c_level0_row3" class="row_heading level0 row3" >All</th>
#       <td id="T_a768c_row3_col0" class="data row3 col0" >0.73</td>
#       <td id="T_a768c_row3_col1" class="data row3 col1" >0.19</td>
#       <td id="T_a768c_row3_col2" class="data row3 col2" >0.38</td>
#     </tr>
#   </tbody>
# </table>
